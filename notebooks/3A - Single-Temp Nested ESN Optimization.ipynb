# %% [markdown]
# # 3A — Single-Temperature Nested ESN Optimization
#
# This notebook performs the expensive, leakage-safe model-selection workflow:
#
# 1. Hold out one material in the outer LOMO loop.
# 2. Run Gaussian-process Bayesian ESN optimization using only the other materials.
# 3. Refit XGBoost with the selected ESN configuration and predict the untouched material.
# 4. Pool all outer out-of-fold predictions for the unbiased performance estimate.
# 5. Run one final grouped search on all materials to obtain a deployment configuration.
# 6. Save predictions, metrics, search histories, and final parameters for Notebook 3B.
#
# Do not run this notebook merely to regenerate plots. Run it when the data, feature
# definition, analysis window, search space, or model-selection design changes.

# %% [markdown]
# # 1. Imports and experiment configuration

# %%
from pathlib import Path
import json
import warnings

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from scipy import linalg
from scipy.signal import savgol_filter
from scipy.stats import kurtosis, norm, skew
from sklearn.compose import TransformedTargetRegressor
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import ConstantKernel, Matern, WhiteKernel
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import GroupKFold, LeaveOneGroupOut
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from xgboost import XGBRegressor

#

# %%
FILE_TITLE = "60C"
OPTIMIZATION_TARGET = "eff"  # Run a separate optimization for "k" if needed.
RANDOM_STATE = 42
RESERVOIR_SEEDS = (42, 43, 44)

# Analysis and feature-definition settings are part of the model specification.
ANALYSIS_WINDOW = (0.0, 5.0)

# Defaults are used only when a function is called without explicit Bayesian params.
ESN_RES_SIZE = 20
ESN_LEAK_RATE = 0.1
ESN_INPUT_MAGNITUDE = 1.0
ESN_SPECTRAL_RADIUS = 0.9
ESN_WASHOUT = 0

# Baseline XGBoost values are overridden by every joint Bayesian candidate.
XGB_PARAMS = {
    "n_estimators": 300,
    "max_depth": 3,
    "learning_rate": 0.03,
    "subsample": 0.85,
    "colsample_bytree": 0.85,
    "min_child_weight": 2.0,
    "reg_alpha": 0.0,
    "reg_lambda": 1.0,
}

# Gaussian-process Bayesian-search controls.
# The joint 13-dimensional space needs more observations than the old ESN-only search.
BAYES_N_TRIALS = 50
BAYES_N_INITIAL = 15
BAYES_ACQUISITION_CANDIDATES = 2048
BAYES_STABILITY_WEIGHT = 0.25
INNER_MATERIAL_FOLDS = 4

cwd = Path.cwd().resolve()
project_candidates = [cwd, cwd.parent]
PROJECT_ROOT = next(
    (path for path in project_candidates if (path / "data").is_dir()), None
)
if PROJECT_ROOT is None:
    raise FileNotFoundError("Run this notebook from the project root or notebooks directory.")

DATA_PATH = PROJECT_ROOT / "data" / "02_preprocessed" / FILE_TITLE
if not DATA_PATH.is_dir():
    raise FileNotFoundError(f"Data directory not found: {DATA_PATH}")

RESULTS_DIR = PROJECT_ROOT / "results" / "single_temp_esn"
RESULTS_DIR.mkdir(parents=True, exist_ok=True)
RESULT_STEM = f"{FILE_TITLE}_{OPTIMIZATION_TARGET}_v5"
PARAMETER_FILE = RESULTS_DIR / f"{RESULT_STEM}_final_parameters.json"

print("Data:", DATA_PATH)
print("Results:", RESULTS_DIR)
print("Final parameter file:", PARAMETER_FILE)
# Out:
# Data: /Users/markkeanujamesexconde/Library/CloudStorage/OneDrive-Personal/Documents/Academe Files/4. Doctoral/Research 1 - Warmth Sensor/Warmth-Sensor-Object-Detection/data/02_preprocessed/60C
# Results: /Users/markkeanujamesexconde/Library/CloudStorage/OneDrive-Personal/Documents/Academe Files/4. Doctoral/Research 1 - Warmth Sensor/Warmth-Sensor-Object-Detection/results/single_temp_esn
# Final parameter file: /Users/markkeanujamesexconde/Library/CloudStorage/OneDrive-Personal/Documents/Academe Files/4. Doctoral/Research 1 - Warmth Sensor/Warmth-Sensor-Object-Detection/results/single_temp_esn/60C_eff_v5_final_parameters.json

# %% [markdown]
# # 2. Standard material properties and trial loading
#
# The processed CSV values in `k`, `Mass`, `Volume`, `rho`, and `cp` are deliberately
# ignored. After loading the sensor data, the notebook overwrites those fields using
# the authoritative table below.
#
# `Mass=1 kg` and `Volume=1 m³` are placeholders and can be updated later.

# %%
STANDARD_PROPERTIES = {
    "ps_foam":   {"k": 0.034, "Mass": 1.0, "Volume": 1.0, "rho": 25.0,   "cp": 1400.0},
    "pu_foam":   {"k": 0.043, "Mass": 1.0, "Volume": 1.0, "rho": 30.0,   "cp": 1400.0},
    "cork":      {"k": 0.043, "Mass": 1.0, "Volume": 1.0, "rho": 240.0,  "cp": 1800.0},
    "wood":      {"k": 0.150, "Mass": 1.0, "Volume": 1.0, "rho": 700.0,  "cp": 1700.0},
    "pdms":      {"k": 0.150, "Mass": 1.0, "Volume": 1.0, "rho": 970.0,  "cp": 1460.0},
    "gypsum":    {"k": 0.170, "Mass": 1.0, "Volume": 1.0, "rho": 800.0,  "cp": 1090.0},
    "cement":    {"k": 0.290, "Mass": 1.0, "Volume": 1.0, "rho": 1440.0, "cp": 750.0},
    "graphite":  {"k": 100.0, "Mass": 1.0, "Volume": 1.0, "rho": 1820.0, "cp": 710.0},
    "bismuth":   {"k": 8.1,   "Mass": 1.0, "Volume": 1.0, "rho": 9780.0, "cp": 130.0},
    "titanium":  {"k": 21.9,  "Mass": 1.0, "Volume": 1.0, "rho": 4506.0, "cp": 523.0},
    "nickel":    {"k": 90.9,  "Mass": 1.0, "Volume": 1.0, "rho": 8908.0, "cp": 461.0},
    "iron":      {"k": 80.4,  "Mass": 1.0, "Volume": 1.0, "rho": 7874.0, "cp": 449.0},
    "aluminum":  {"k": 237.0, "Mass": 1.0, "Volume": 1.0, "rho": 2700.0, "cp": 897.0},
    "copper":    {"k": 401.0, "Mass": 1.0, "Volume": 1.0, "rho": 8960.0, "cp": 385.0},
}

SAMPLE_ALIASES = {
    "ps": "ps_foam", "ps foam": "ps_foam", "ps_foam": "ps_foam",
    "pu": "pu_foam", "pu foam": "pu_foam", "pu_foam": "pu_foam",
    "cork": "cork", "cork fine": "cork", "cork_fine": "cork",
    "wood": "wood",
    "pdms": "pdms",
    "gypsum": "gypsum",
    "cement": "cement",
    "graphite": "graphite", "carbon": "graphite",
    "bi": "bismuth", "bismuth": "bismuth",
    "ti": "titanium", "titanium": "titanium",
    "ni": "nickel", "nickel": "nickel",
    "fe": "iron", "iron": "iron",
    "al": "aluminum", "aluminum": "aluminum",
    "cu": "copper", "copper": "copper",
}

standard_table = (
    pd.DataFrame.from_dict(STANDARD_PROPERTIES, orient="index")
    .rename_axis("Material")
    .reset_index()
)
display(standard_table)

required = {"Sample", "Trial", "Time", "Primary", "Secondary"}
frames = []

for path in sorted(DATA_PATH.glob("*.csv")):
    frame = pd.read_csv(path)
    missing = required - set(frame.columns)
    if missing:
        warnings.warn(f"Skipping {path.name}; missing {sorted(missing)}")
        continue
    frames.append(frame)

if not frames:
    raise ValueError("No valid trial files were found.")

DATA = pd.concat(frames, ignore_index=True)
DATA = DATA.replace([np.inf, -np.inf], np.nan)
for column in ("Trial", "Time", "Primary", "Secondary"):
    DATA[column] = pd.to_numeric(DATA[column], errors="coerce")
DATA = DATA.dropna(subset=list(required)).copy()
DATA["Trial"] = DATA["Trial"].astype(int)

normalized_sample = (
    DATA["Sample"].astype(str).str.strip().str.lower().str.replace("_", " ")
)
DATA["Sample"] = normalized_sample.map(SAMPLE_ALIASES)
unknown_mask = DATA["Sample"].isna()
if unknown_mask.any():
    unknown = sorted(normalized_sample[unknown_mask].unique())
    raise KeyError(f"No standard-property mapping for samples: {unknown}")

# Overwrite processed-file properties unconditionally.
for property_name in ("k", "Mass", "Volume", "rho", "cp"):
    DATA[property_name] = DATA["Sample"].map(
        lambda sample: STANDARD_PROPERTIES[sample][property_name]
    )

DATA["trial_id"] = (
    DATA["Sample"].astype(str) + "_trial_" + DATA["Trial"].astype(str)
)
DATA["eff"] = np.sqrt(DATA["k"] * DATA["rho"] * DATA["cp"])
DATA = DATA.sort_values(["trial_id", "Time"]).reset_index(drop=True)

# Literature k should be stable by material. Density may vary across measured
# specimens/trials, so the derived eff target is allowed to vary by trial.
k_counts = DATA.groupby("Sample")["k"].nunique()
if (k_counts != 1).any():
    raise ValueError(
        f"k is not constant within: {k_counts[k_counts != 1].index.tolist()}"
    )

summary = (
    DATA.groupby(["trial_id", "Sample", "Trial"], as_index=False)
    .agg(
        n_timesteps=("Time", "size"),
        k=("k", "first"),
        eff=("eff", "first"),
    )
)
print(f"Rows: {len(DATA):,}")
print(f"Trials: {DATA['trial_id'].nunique()}")
print(f"Independent materials: {DATA['Sample'].nunique()}")
display(summary.head())
# Out:
#     Material        k  Mass  Volume     rho      cp
# 0    ps_foam    0.034   1.0     1.0    25.0  1400.0
# 1    pu_foam    0.043   1.0     1.0    30.0  1400.0
# 2       cork    0.043   1.0     1.0   240.0  1800.0
# 3       wood    0.150   1.0     1.0   700.0  1700.0
# 4       pdms    0.150   1.0     1.0   970.0  1460.0
# 5     gypsum    0.170   1.0     1.0   800.0  1090.0
# 6     cement    0.290   1.0     1.0  1440.0   750.0
# 7   graphite  100.000   1.0     1.0  1820.0   710.0
# 8    bismuth    8.100   1.0     1.0  9780.0   130.0
# 9   titanium   21.900   1.0     1.0  4506.0   523.0
# 10    nickel   90.900   1.0     1.0  8908.0   461.0
# 11      iron   80.400   1.0     1.0  7874.0   449.0
# 12  aluminum  237.000   1.0     1.0  2700.0   897.0
# 13    copper  401.000   1.0     1.0  8960.0   385.0
# Rows: 17,328
# Trials: 84
# Independent materials: 14
#            trial_id    Sample  Trial  n_timesteps      k           eff
# 0  aluminum_trial_1  aluminum      1          210  237.0  23958.094665
# 1  aluminum_trial_2  aluminum      2          230  237.0  23958.094665
# 2  aluminum_trial_3  aluminum      3          194  237.0  23958.094665
# 3  aluminum_trial_4  aluminum      4          200  237.0  23958.094665
# 4  aluminum_trial_5  aluminum      5          210  237.0  23958.094665

# %% [markdown]
# # 3. Detect contact and align every trial
#
# The elbow is used only to establish a common time origin. Prediction uses the fixed
# 0–5 second response after contact. Trials are never aligned using `k` or `eff`.

# %%
def find_contact_time(
    trial,
    smooth_window=15,
    polyorder=2,
    threshold_frac=0.30,
    skip_samples=5,
):
    clean = (
        trial[["Time", "Primary"]]
        .apply(pd.to_numeric, errors="coerce")
        .dropna()
        .sort_values("Time")
        .drop_duplicates("Time")
        .reset_index(drop=True)
    )
    time = clean["Time"].to_numpy(float)
    signal = clean["Primary"].to_numpy(float)
    if len(signal) < skip_samples + 7 or np.any(np.diff(time) <= 0):
        raise ValueError("Insufficient or invalid time samples.")

    work_time = time[skip_samples:]
    work_signal = signal[skip_samples:]
    window = min(int(smooth_window), len(work_signal))
    if window % 2 == 0:
        window -= 1
    minimum = polyorder + 2
    if minimum % 2 == 0:
        minimum += 1
    if window < minimum:
        raise ValueError("Sequence is too short for smoothing.")

    smooth = savgol_filter(work_signal, window, polyorder, mode="interp")
    derivative = np.gradient(smooth, work_time)
    strongest = int(np.argmin(derivative))
    active = derivative < threshold_frac * derivative[strongest]
    elbow = 0
    for position in range(strongest, -1, -1):
        if not active[position]:
            elbow = position + 1
            break
    return float(work_time[elbow])

# %%
aligned_trials = {}
alignment_rows = []

for trial_id, trial in DATA.groupby("trial_id", sort=False):
    trial = trial.sort_values("Time").drop_duplicates("Time").copy()
    try:
        contact_time = find_contact_time(trial)
    except ValueError as exc:
        warnings.warn(f"Skipping {trial_id}: {exc}")
        continue

    trial["time_from_contact"] = trial["Time"] - contact_time
    start, end = ANALYSIS_WINDOW
    trial = trial[
        trial["time_from_contact"].between(start, end, inclusive="both")
    ].copy()
    if len(trial) < 10:
        warnings.warn(f"Skipping {trial_id}: too few post-contact samples")
        continue
    aligned_trials[trial_id] = trial.reset_index(drop=True)
    alignment_rows.append({
        "trial_id": trial_id,
        "Sample": trial["Sample"].iloc[0],
        "Trial": int(trial["Trial"].iloc[0]),
        "contact_time": contact_time,
        "n_analysis_samples": len(trial),
    })

ALIGNMENT = pd.DataFrame(alignment_rows)
print(f"Aligned trials retained: {len(aligned_trials)}")
display(ALIGNMENT.head())
# Out:
# Aligned trials retained: 84
#            trial_id    Sample  Trial  contact_time  n_analysis_samples
# 0  aluminum_trial_1  aluminum      1       9.40070                  51
# 1  aluminum_trial_2  aluminum      2      10.90066                  50
# 2  aluminum_trial_3  aluminum      3       8.10070                  51
# 3  aluminum_trial_4  aluminum      4       7.80070                  51
# 4  aluminum_trial_5  aluminum      5       9.00067                  50

# %% [markdown]
# ## Check several alignments visually

# %%
def plot_aligned_trials(material=None, maximum_trials=6):
    selected = list(aligned_trials.values())
    if material is not None:
        selected = [x for x in selected if x["Sample"].iloc[0] == material]
    selected = selected[:maximum_trials]

    fig, axes = plt.subplots(1, 2, figsize=(13, 4), sharex=True)
    for trial in selected:
        label = trial["trial_id"].iloc[0]
        axes[0].plot(trial["time_from_contact"], trial["Primary"], alpha=0.75, label=label)
        axes[1].plot(trial["time_from_contact"], trial["Secondary"], alpha=0.75, label=label)
    for ax, title in zip(axes, ["Primary", "Secondary"]):
        ax.axvline(0, color="black", linestyle=":")
        ax.set(xlabel="Time from contact (s)", ylabel="Sensor response", title=title)
    axes[1].legend(fontsize=7, bbox_to_anchor=(1.04, 1), loc="upper left")
    plt.tight_layout()
    plt.show()

plot_aligned_trials(material=ALIGNMENT["Sample"].iloc[0])

# %% [markdown]
# # 4. Interpretable thermal-response features
#
# Because the analysis interval is 0–5 s, every feature summarizes the complete
# transient. The interval is not subdivided into early, middle, and late windows.

# %%
def _smooth(values, window=11, polyorder=2):
    values = np.asarray(values, float)
    selected = min(window, len(values))
    if selected % 2 == 0:
        selected -= 1
    minimum = polyorder + 2
    if minimum % 2 == 0:
        minimum += 1
    return (
        savgol_filter(values, selected, polyorder, mode="interp")
        if selected >= minimum else values.copy()
    )


def _response_slope(time, values):
    valid = np.isfinite(time) & np.isfinite(values)
    if valid.sum() < 3:
        return np.nan
    return float(np.polyfit(time[valid], values[valid], 1)[0])


def extract_thermal_features(trial):
    time = trial["time_from_contact"].to_numpy(float)
    primary = _smooth(trial["Primary"].to_numpy(float))
    secondary = _smooth(trial["Secondary"].to_numpy(float))
    difference = primary - secondary
    result = {}

    for name, signal in {
        "primary": primary,
        "secondary": secondary,
        "difference": difference,
    }.items():
        change = signal - signal[0]
        rate = np.gradient(signal, time)
        result[f"{name}_final_change"] = float(change[-1])
        result[f"{name}_max_abs_change"] = float(np.max(np.abs(change)))
        result[f"{name}_response_auc"] = float(np.trapezoid(np.abs(change), time))
        result[f"{name}_response_slope"] = _response_slope(time, signal)
        result[f"{name}_max_abs_rate"] = float(np.max(np.abs(rate)))
        result[f"{name}_rate_auc"] = float(np.trapezoid(np.abs(rate), time))

    # Dimensionless/cross-sensor summaries.
    primary_auc = result["primary_response_auc"]
    result["secondary_primary_auc_ratio"] = (
        result["secondary_response_auc"] / primary_auc
        if not np.isclose(primary_auc, 0) else np.nan
    )
    result["initial_sensor_difference"] = float(difference[0])
    result["final_sensor_difference"] = float(difference[-1])
    return result


thermal_rows = []
for trial_id, trial in aligned_trials.items():
    features = extract_thermal_features(trial)
    features.update({
        "trial_id": trial_id,
        "Sample": trial["Sample"].iloc[0],
        "Trial": int(trial["Trial"].iloc[0]),
        "k": float(trial["k"].iloc[0]),
        "eff": float(trial["eff"].iloc[0]),
    })
    thermal_rows.append(features)

THERMAL_FEATURES = pd.DataFrame(thermal_rows)
print(f"Thermal features: {len(THERMAL_FEATURES.columns) - 5}")
display(THERMAL_FEATURES.head())
# Out:
# Thermal features: 21
#    primary_final_change  primary_max_abs_change  primary_response_auc  \
# 0             -0.000025                0.000025              0.000102
# 1             -0.000024                0.000024              0.000096
# 2             -0.000024                0.000024              0.000098
# 3             -0.000024                0.000024              0.000097
# 4             -0.000024                0.000024              0.000096
#
#    primary_response_slope  primary_max_abs_rate  primary_rate_auc  \
# 0               -0.000003              0.000026          0.000025
# 1               -0.000003              0.000027          0.000024
# 2               -0.000003              0.000024          0.000024
# 3               -0.000003              0.000022          0.000024
# 4               -0.000003              0.000024          0.000024
#
#    secondary_final_change  secondary_max_abs_change  secondary_response_auc  \
# 0               -0.000009                  0.000009                0.000018
# 1               -0.000009                  0.000009                0.000017
# 2               -0.000009                  0.000009                0.000017
# 3               -0.000009                  0.000009                0.000018
# 4               -0.000009                  0.000009                0.000017
#
#    secondary_response_slope  ...  difference_max_abs_rate  \
# 0                 -0.000002  ...                 0.000026
# 1                 -0.000002  ...                 0.000027
# 2                 -0.000002  ...                 0.000024
# 3                 -0.000002  ...                 0.000022
# 4                 -0.000002  ...                 0.000024
#
#    difference_rate_auc  secondary_primary_auc_ratio  \
# 0             0.000025                     0.173943
# 1             0.000024                     0.176338
# 2             0.000024                     0.174287
# 3             0.000024                     0.183508
# 4             0.000024                     0.176910
#
#    initial_sensor_difference  final_sensor_difference          trial_id  \
# 0                  -0.000038                -0.000054  aluminum_trial_1
# 1                  -0.000039                -0.000053  aluminum_trial_2
# 2                  -0.000039                -0.000053  aluminum_trial_3
# 3                  -0.000039                -0.000053  aluminum_trial_4
# 4                  -0.000039                -0.000053  aluminum_trial_5
#
#      Sample  Trial      k           eff
# 0  aluminum      1  237.0  23958.094665
# 1  aluminum      2  237.0  23958.094665
# 2  aluminum      3  237.0  23958.094665
# 3  aluminum      4  237.0  23958.094665
# 4  aluminum      5  237.0  23958.094665
#
# [5 rows x 26 columns]

# %% [markdown]
# # 5. Manual ESN reservoir and compact trajectory summaries
#
# For every trial, the reservoir produces a time-by-unit state matrix. This version
# does **not** flatten the raw states. Instead, it describes every reservoir-unit
# trajectory with nine complementary summaries:
#
# - mean and standard deviation: activation level and variability
# - range: peak-to-peak activation magnitude
# - net change and linear slope: endpoint change and overall direction
# - absolute area: accumulated activation magnitude
# - time of maximum absolute activation: timing of the strongest response
# - skewness and excess kurtosis: trajectory-distribution shape
#
# Thus, a reservoir with `r` units produces `9 × r` predictors per trial. Removed
# summaries were exact or strong proxies of retained quantities over a common time
# window (for example, initial/final versus net change; min/max versus range; signed
# area versus mean; and mean absolute activation versus absolute area). Time is
# retained indirectly through slope, absolute area, peak timing, and net change. Input
# scaling is fitted inside each outer training fold.

# %%
class ManualReservoir:
    def __init__(
        self,
        res_size=30,
        leak_rate=0.9,
        input_magnitude=1.5,
        spectral_radius=1.3,
        washout=0,
        random_state=42,
    ):
        self.res_size = int(res_size)
        self.leak_rate = float(leak_rate)
        self.input_magnitude = float(input_magnitude)
        self.spectral_radius = float(spectral_radius)
        self.washout = int(washout)
        rng = np.random.default_rng(random_state)
        self.Win = (rng.random((self.res_size, 1 + 5)) - 0.5) * self.input_magnitude
        W = rng.random((self.res_size, self.res_size)) - 0.5
        radius = np.max(np.abs(linalg.eigvals(W)))
        if not np.isfinite(radius) or np.isclose(radius, 0):
            raise ValueError("Invalid reservoir spectral radius.")
        self.W = (W / radius.real) * self.spectral_radius

    def run(self, sequence):
        sequence = np.asarray(sequence, float)
        if sequence.ndim != 2 or sequence.shape[1] != 5:
            raise ValueError("Expected sequence with five input channels.")
        if len(sequence) <= self.washout:
            raise ValueError(
                f"Sequence has {len(sequence)} samples, but washout={self.washout}. "
                "Washout must be smaller than the sequence length."
            )
        x = np.zeros((self.res_size, 1))
        states = []
        for row in sequence:
            u = row.reshape(-1, 1)
            x = (
                (1 - self.leak_rate) * x
                + self.leak_rate * np.tanh(
                    self.Win @ np.vstack((1.0, u)) + self.W @ x
                )
            )
            states.append(x[:, 0].copy())
        return np.asarray(states)[self.washout:]


def raw_esn_input(trial):
    time = trial["time_from_contact"].to_numpy(float)
    primary = _smooth(trial["Primary"].to_numpy(float))
    secondary = _smooth(trial["Secondary"].to_numpy(float))
    difference = primary - secondary
    primary_rate = np.gradient(primary, time)
    secondary_rate = np.gradient(secondary, time)
    return np.column_stack([
        primary, secondary, difference, primary_rate, secondary_rate
    ])


def summarize_reservoir_trajectories(time, states):
    """Return finite statistical/dynamical summaries for every reservoir unit."""
    time = np.asarray(time, float)
    states = np.asarray(states, float)
    if states.ndim != 2 or len(time) != len(states):
        raise ValueError("Time and reservoir states must have matching rows.")
    if len(time) < 2 or np.any(~np.isfinite(time)) or np.any(np.diff(time) <= 0):
        raise ValueError("Reservoir-state time must be finite and strictly increasing.")
    if np.any(~np.isfinite(states)):
        raise ValueError("Reservoir states contain non-finite values.")

    result = {}
    for unit in range(states.shape[1]):
        values = states[:, unit]
        maximum_absolute_index = int(np.argmax(np.abs(values)))
        standard_deviation = float(np.std(values, ddof=0))

        # Constant or nearly constant trajectories have well-defined zero shape
        # rather than scipy's otherwise undefined skewness/kurtosis warnings.
        if len(values) < 3 or np.isclose(standard_deviation, 0.0):
            skewness = 0.0
        else:
            skewness = float(skew(values, bias=False))
        if len(values) < 4 or np.isclose(standard_deviation, 0.0):
            excess_kurtosis = 0.0
        else:
            excess_kurtosis = float(kurtosis(values, fisher=True, bias=False))

        summaries = {
            "mean": float(np.mean(values)),
            "std": standard_deviation,
            "range": float(np.ptp(values)),
            "net_change": float(values[-1] - values[0]),
            "slope": float(np.polyfit(time, values, 1)[0]),
            "absolute_area": float(np.trapezoid(np.abs(values), time)),
            "time_of_max_absolute": float(time[maximum_absolute_index]),
            "skewness": skewness,
            "excess_kurtosis": excess_kurtosis,
        }
        
        for name, value in summaries.items():
            if not np.isfinite(value):
                raise ValueError(f"Non-finite {name} for reservoir unit {unit}.")
            result[f"esn_{name}_u{unit:03d}"] = value
    return result

# %% [markdown]
# # 6. Leakage-safe XGBoost regression and valid metrics

# %%
def regression_metrics(y_true, y_pred):
    """Metrics requiring variation in y_true; intended for pooled or mixed-target data."""
    y_true = np.asarray(y_true, float)
    y_pred = np.asarray(y_pred, float)
    if len(y_true) == 0 or np.any(~np.isfinite(y_true)) or np.any(~np.isfinite(y_pred)):
        raise ValueError("Metrics require non-empty, finite targets and predictions.")
    target_range = float(np.ptp(y_true))
    if len(y_true) < 2 or target_range <= 0:
        raise ValueError(
            "R² and test-range NRMSE require at least two distinct target values. "
            "Use constant_target_fold_metrics for a single-material LOMO fold."
        )
    rmse = float(np.sqrt(mean_squared_error(y_true, y_pred)))
    return {
        "n": len(y_true),
        "mae": float(mean_absolute_error(y_true, y_pred)),
        "rmse": rmse,
        "nrmse_range": rmse / target_range,
        "r2": float(r2_score(y_true, y_pred)),
        "median_ape_pct": float(np.median(np.abs((y_true - y_pred) / y_true)) * 100),
    }


def constant_target_fold_metrics(y_true, y_pred, training_target_range):
    """Valid diagnostics for one outer LOMO fold with a constant test target."""
    y_true = np.asarray(y_true, float)
    y_pred = np.asarray(y_pred, float)
    training_target_range = float(training_target_range)
    if len(y_true) == 0 or np.any(~np.isfinite(y_true)) or np.any(~np.isfinite(y_pred)):
        raise ValueError("Fold metrics require non-empty, finite values.")
    if training_target_range <= 0:
        raise ValueError("The outer-training target range must be positive.")
    residual = y_pred - y_true
    rmse = float(np.sqrt(np.mean(residual ** 2)))
    return {
        "n": len(y_true),
        "mae": float(np.mean(np.abs(residual))),
        "rmse": rmse,
        "nrmse_training_range": rmse / training_target_range,
        "mean_error_bias": float(np.mean(residual)),
        "median_ape_pct": float(np.median(np.abs(residual / y_true)) * 100),
    }


def make_regressor(xgb_params=None, random_state=RANDOM_STATE):
    params = {**XGB_PARAMS, **(xgb_params or {})}
    xgb = XGBRegressor(
        objective="reg:squarederror",
        random_state=int(random_state),
        n_jobs=-1,
        tree_method="hist",
        verbosity=0,
        **params,
    )
    base = Pipeline([
        ("imputer", SimpleImputer(strategy="median")),
        ("xgb", xgb),
    ])
    return TransformedTargetRegressor(
        regressor=base,
        func=np.log1p,
        inverse_func=np.expm1,
        check_inverse=False,
    )

# %% [markdown]
# # 7. ESN feature generation and evaluation functions

# %%
def outer_splits(table, protocol):
    if protocol == "held_out_repetition":
        splitter = GroupKFold(n_splits=table["Trial"].nunique())
        return splitter.split(table, groups=table["Trial"])
    if protocol == "held_out_material":
        splitter = LeaveOneGroupOut()
        return splitter.split(table, groups=table["Sample"])
    raise ValueError("Unknown protocol.")


def build_esn_feature_table(train_ids, all_ids, esn_params=None, random_state=RANDOM_STATE):
    params = {
        "res_size": ESN_RES_SIZE,
        "leak_rate": ESN_LEAK_RATE,
        "input_magnitude": ESN_INPUT_MAGNITUDE,
        "spectral_radius": ESN_SPECTRAL_RADIUS,
        "washout": ESN_WASHOUT,
    }
    params.update(esn_params or {})
    scaler = StandardScaler().fit(np.vstack([
        raw_esn_input(aligned_trials[trial_id]) for trial_id in train_ids
    ]))
    reservoir = ManualReservoir(**params, random_state=random_state)
    rows = []
    for trial_id in all_ids:
        trial = aligned_trials[trial_id]
        sequence = scaler.transform(raw_esn_input(trial))
        states = reservoir.run(sequence)
        state_time = trial["time_from_contact"].to_numpy(float)[params["washout"]:]
        features = summarize_reservoir_trajectories(state_time, states)
        features.update({
            "trial_id": trial_id,
            "Sample": trial["Sample"].iloc[0],
            "Trial": int(trial["Trial"].iloc[0]),
            "k": float(trial["k"].iloc[0]),
            "eff": float(trial["eff"].iloc[0]),
        })
        rows.append(features)
    return pd.DataFrame(rows)


def evaluate_feature_family(feature_family, target, protocol):
    metadata = THERMAL_FEATURES[["trial_id", "Sample", "Trial", "k", "eff"]].copy()
    fold_rows, prediction_rows = [], []

    for fold, (train_idx, test_idx) in enumerate(outer_splits(metadata, protocol), start=1):
        train_meta = metadata.iloc[train_idx]
        test_meta = metadata.iloc[test_idx]
        train_ids = train_meta["trial_id"].tolist()
        test_ids = test_meta["trial_id"].tolist()

        if set(train_ids) & set(test_ids):
            raise RuntimeError("Trial leakage detected.")
        if protocol == "held_out_material" and set(train_meta["Sample"]) & set(test_meta["Sample"]):
            raise RuntimeError("Material leakage detected.")

        if feature_family == "thermal":
            fold_features = THERMAL_FEATURES
        elif feature_family == "esn":
            fold_features = build_esn_feature_table(train_ids, train_ids + test_ids)
        else:
            raise ValueError("feature_family must be thermal or esn")

        indexed = fold_features.set_index("trial_id")
        excluded = {"Sample", "Trial", "k", "eff"}
        feature_cols = [
            c for c in fold_features.select_dtypes(include=np.number).columns
            if c not in excluded
        ]
        X_train = indexed.loc[train_ids, feature_cols].reset_index(drop=True)
        X_test = indexed.loc[test_ids, feature_cols].reset_index(drop=True)
        y_train = indexed.loc[train_ids, target].reset_index(drop=True)
        y_test = indexed.loc[test_ids, target].reset_index(drop=True)

        model = make_regressor()
        model.fit(X_train, y_train)
        pred = np.clip(model.predict(X_test), y_train.min(), y_train.max())

        if protocol == "held_out_material":
            fold_diagnostics = constant_target_fold_metrics(
                y_test, pred, np.ptp(y_train.to_numpy(float))
            )
        else:
            fold_diagnostics = regression_metrics(y_test, pred)
        fold_rows.append({
            "fold": fold,
            "feature_family": feature_family,
            "target": target,
            "protocol": protocol,
            "test_materials": ", ".join(sorted(set(test_meta["Sample"]))),
            **fold_diagnostics,
        })
        prediction_rows.append(pd.DataFrame({
            "trial_id": test_ids,
            "Sample": test_meta["Sample"].to_numpy(),
            "Trial": test_meta["Trial"].to_numpy(),
            "fold": fold,
            "y_true": y_test,
            "y_pred": pred,
        }))

    fold_metrics = pd.DataFrame(fold_rows)
    predictions = pd.concat(prediction_rows, ignore_index=True)
    overall = pd.DataFrame([{
        "feature_family": feature_family,
        "target": target,
        "protocol": protocol,
        **regression_metrics(predictions["y_true"], predictions["y_pred"]),
    }])
    return fold_metrics, overall, predictions

# %% [markdown]
# # 8. Nested joint Bayesian optimization and unbiased LOMO evaluation
#
# Every Bayesian candidate contains both ESN and XGBoost parameters. The objective is
# the mean material-grouped inner-fold NRMSE plus a penalty for fold instability.
#
# The outer test material never participates in input scaling, feature construction,
# XGBoost fitting, or joint hyperparameter selection. Fold-level LOMO R² is not
# reported because one material has a constant target. Pooled outer OOF R² is valid.
#
# The XGBoost ranges are deliberately conservative for 78 outer-training trials:
# shallow trees, row/column subsampling, and explicit L1/L2 regularization.

# %%
ESN_BAYES_SPACE = {
    "res_size": ("integer", 10, 80),
    "leak_rate": ("float", 0.05, 0.95),
    "input_magnitude": ("float", 0.25, 2.00),
    "spectral_radius": ("float", 0.30, 1.50),
    "washout": ("integer", 0, 5),
}

XGB_BAYES_SPACE = {
    "n_estimators": ("integer", 100, 600),
    "max_depth": ("integer", 1, 4),
    "learning_rate": ("log_float", 0.01, 0.15),
    "min_child_weight": ("log_float", 1.0, 20.0),
    "subsample": ("float", 0.60, 1.00),
    "colsample_bytree": ("float", 0.30, 1.00),
    "reg_alpha": ("log_float", 1e-4, 10.0),
    "reg_lambda": ("log_float", 0.10, 100.0),
}

BAYES_SPACE = {**ESN_BAYES_SPACE, **XGB_BAYES_SPACE}
ESN_BAYES_KEYS = tuple(ESN_BAYES_SPACE)
XGB_BAYES_KEYS = tuple(XGB_BAYES_SPACE)
BAYES_KEYS = tuple(BAYES_SPACE)


def _decode_bayes_point(point):
    """Map one unit-hypercube point to a valid joint ESN-XGBoost candidate."""
    params = {}
    for key, coordinate in zip(BAYES_KEYS, np.clip(point, 0.0, 1.0)):
        kind, low, high = BAYES_SPACE[key]
        coordinate = float(coordinate)
        if kind == "integer":
            value = int(round(low + coordinate * (high - low)))
        elif kind == "log_float":
            value = float(np.exp(np.log(low) + coordinate * (np.log(high) - np.log(low))))
        elif kind == "float":
            value = float(low + coordinate * (high - low))
        else:
            raise ValueError(f"Unknown Bayesian parameter type: {kind}")
        params[key] = value
    return params


def _split_joint_parameters(params):
    missing = set(BAYES_KEYS) - set(params)
    if missing:
        raise KeyError(f"Joint candidate is missing parameters: {sorted(missing)}")
    esn_params = {key: params[key] for key in ESN_BAYES_KEYS}
    xgb_params = {key: params[key] for key in XGB_BAYES_KEYS}
    esn_params["res_size"] = int(esn_params["res_size"])
    esn_params["washout"] = int(esn_params["washout"])
    xgb_params["n_estimators"] = int(xgb_params["n_estimators"])
    xgb_params["max_depth"] = int(xgb_params["max_depth"])
    return esn_params, xgb_params


def _predict_joint_fold(train_meta, valid_meta, target, params, random_states):
    train_ids = train_meta["trial_id"].tolist()
    valid_ids = valid_meta["trial_id"].tolist()
    if set(train_ids) & set(valid_ids):
        raise RuntimeError("Trial leakage detected during Bayesian search.")
    if set(train_meta["Sample"]) & set(valid_meta["Sample"]):
        raise RuntimeError("Material leakage detected during Bayesian search.")

    esn_params, xgb_params = _split_joint_parameters(params)
    seed_predictions = []
    for random_state in random_states:
        features = build_esn_feature_table(
            train_ids,
            train_ids + valid_ids,
            esn_params=esn_params,
            random_state=random_state,
        ).set_index("trial_id")
        feature_cols = [column for column in features if column.startswith("esn_")]
        X_train = features.loc[train_ids, feature_cols].reset_index(drop=True)
        X_valid = features.loc[valid_ids, feature_cols].reset_index(drop=True)
        y_train = features.loc[train_ids, target].reset_index(drop=True)

        model = make_regressor(xgb_params=xgb_params, random_state=random_state)
        model.fit(X_train, y_train)
        seed_predictions.append(np.clip(
            model.predict(X_valid), y_train.min(), y_train.max()
        ))

    return valid_meta[target].to_numpy(float), np.mean(seed_predictions, axis=0)


def _inner_objective(metadata, target, params, n_splits, random_states, stability_weight):
    splitter = GroupKFold(n_splits=n_splits)
    rows = []
    for fold, (train_idx, valid_idx) in enumerate(
        splitter.split(metadata, groups=metadata["Sample"]), start=1
    ):
        y_true, y_pred = _predict_joint_fold(
            metadata.iloc[train_idx], metadata.iloc[valid_idx],
            target, params, random_states,
        )
        rows.append({"fold": fold, **regression_metrics(y_true, y_pred)})

    fold_metrics = pd.DataFrame(rows)
    values = fold_metrics["nrmse_range"]
    if len(values) != n_splits or np.any(~np.isfinite(values)):
        raise ValueError("Inner-fold NRMSE contains invalid values.")
    mean_nrmse = float(values.mean())
    sd_nrmse = float(values.std(ddof=0))
    return mean_nrmse + stability_weight * sd_nrmse, fold_metrics


def bayesian_optimize_joint(
    metadata,
    target="eff",
    n_trials=BAYES_N_TRIALS,
    n_initial=BAYES_N_INITIAL,
    inner_splits=4,
    random_states=(42, 43, 44),
    stability_weight=BAYES_STABILITY_WEIGHT,
    acquisition_candidates=BAYES_ACQUISITION_CANDIDATES,
    optimizer_seed=2026,
):
    """Minimize grouped-CV loss with GP expected improvement over joint parameters."""
    if n_trials < 2 or not 1 <= n_initial <= n_trials:
        raise ValueError("Require n_trials >= 2 and 1 <= n_initial <= n_trials.")
    if inner_splits < 2 or inner_splits > metadata["Sample"].nunique():
        raise ValueError("Invalid number of inner material folds.")
    if not random_states:
        raise ValueError("At least one reservoir seed is required.")

    rng = np.random.default_rng(optimizer_seed)
    points, losses, rows = [], [], []

    for trial_number in range(1, n_trials + 1):
        if trial_number <= n_initial:
            point = rng.random(len(BAYES_KEYS))
            acquisition = "random_initialization"
        else:
            X_observed = np.asarray(points)
            y_observed = np.asarray(losses)
            kernel = (
                ConstantKernel(1.0, (1e-2, 1e2))
                * Matern(length_scale=np.ones(len(BAYES_KEYS)), nu=2.5)
                + WhiteKernel(noise_level=1e-5, noise_level_bounds=(1e-8, 1e-1))
            )
            gp = GaussianProcessRegressor(
                kernel=kernel,
                normalize_y=True,
                random_state=optimizer_seed + trial_number,
                n_restarts_optimizer=2,
            )
            with warnings.catch_warnings():
                warnings.simplefilter("ignore")
                gp.fit(X_observed, y_observed)
            candidates = rng.random((acquisition_candidates, len(BAYES_KEYS)))
            mean, std = gp.predict(candidates, return_std=True)
            improvement = np.min(y_observed) - mean - 0.01
            z = np.divide(improvement, std, out=np.zeros_like(std), where=std > 0)
            expected_improvement = improvement * norm.cdf(z) + std * norm.pdf(z)
            point = candidates[int(np.argmax(expected_improvement))]
            acquisition = "expected_improvement"

        params = _decode_bayes_point(point)
        loss, fold_metrics = _inner_objective(
            metadata, target, params, inner_splits,
            tuple(random_states), stability_weight,
        )
        points.append(point)
        losses.append(loss)
        rows.append({
            "trial": trial_number,
            "acquisition": acquisition,
            **params,
            "mean_inner_nrmse": float(fold_metrics["nrmse_range"].mean()),
            "sd_inner_nrmse": float(fold_metrics["nrmse_range"].std(ddof=0)),
            "mean_inner_r2": float(fold_metrics["r2"].mean()),
            "performance_index": loss,
        })
        print(f"  Joint Bayesian trial {trial_number:02d}/{n_trials}: J={loss:.4f}")

    history = pd.DataFrame(rows).sort_values("performance_index").reset_index(drop=True)
    best_params = {key: history.loc[0, key] for key in BAYES_KEYS}
    best_params["res_size"] = int(best_params["res_size"])
    best_params["washout"] = int(best_params["washout"])
    best_params["n_estimators"] = int(best_params["n_estimators"])
    best_params["max_depth"] = int(best_params["max_depth"])
    return history, best_params


def nested_lomo_joint_bayesian_search(
    target="eff",
    n_trials=BAYES_N_TRIALS,
    n_initial=BAYES_N_INITIAL,
    inner_splits=4,
    random_states=(42, 43, 44),
    stability_weight=BAYES_STABILITY_WEIGHT,
):
    metadata = THERMAL_FEATURES[
        ["trial_id", "Sample", "Trial", "k", "eff"]
    ].reset_index(drop=True)
    outer_splitter = LeaveOneGroupOut()
    search_rows, outer_rows, prediction_rows = [], [], []

    splits = list(outer_splitter.split(metadata, groups=metadata["Sample"]))
    for outer_fold, (train_idx, test_idx) in enumerate(splits, start=1):
        outer_train = metadata.iloc[train_idx].reset_index(drop=True)
        outer_test = metadata.iloc[test_idx].reset_index(drop=True)
        held_out = outer_test["Sample"].iloc[0]
        print(f"Outer fold {outer_fold}/{len(splits)}: held out {held_out}")

        history, best_params = bayesian_optimize_joint(
            outer_train,
            target=target,
            n_trials=n_trials,
            n_initial=n_initial,
            inner_splits=inner_splits,
            random_states=random_states,
            stability_weight=stability_weight,
            optimizer_seed=2026 + outer_fold,
        )
        history.insert(0, "outer_fold", outer_fold)
        history.insert(1, "held_out_material", held_out)
        search_rows.append(history)

        y_true, y_pred = _predict_joint_fold(
            outer_train, outer_test, target, best_params, tuple(random_states)
        )
        outer_diagnostics = constant_target_fold_metrics(
            y_true, y_pred, np.ptp(outer_train[target].to_numpy(float))
        )
        outer_rows.append({
            "outer_fold": outer_fold,
            "held_out_material": held_out,
            **best_params,
            **outer_diagnostics,
        })
        prediction_rows.append(pd.DataFrame({
            "trial_id": outer_test["trial_id"].to_numpy(),
            "Sample": outer_test["Sample"].to_numpy(),
            "Trial": outer_test["Trial"].to_numpy(),
            "outer_fold": outer_fold,
            "y_true": y_true,
            "y_pred": y_pred,
        }))

    searches = pd.concat(search_rows, ignore_index=True)
    outer_results = pd.DataFrame(outer_rows)
    predictions = pd.concat(prediction_rows, ignore_index=True)
    nested_metrics = pd.DataFrame([{
        "target": target,
        "protocol": "nested_lomo_joint_bayesian_esn_xgboost",
        "n_bayesian_trials": n_trials,
        "random_states": tuple(random_states),
        **regression_metrics(predictions["y_true"], predictions["y_pred"]),
    }])

    print("Final joint Bayesian search on all materials for deployment parameters")
    final_history, recommended = bayesian_optimize_joint(
        metadata,
        target=target,
        n_trials=n_trials,
        n_initial=n_initial,
        inner_splits=inner_splits,
        random_states=random_states,
        stability_weight=stability_weight,
        optimizer_seed=4042,
    )
    return searches, outer_results, predictions, nested_metrics, final_history, recommended

# %%
BAYES_TARGET = OPTIMIZATION_TARGET
RANDOM_STATES = RESERVOIR_SEEDS

# Runtime is proportional to outer materials × trials × inner folds × seeds.
(
    BAYES_SEARCH_HISTORY,
    BAYES_OUTER_RESULTS,
    BAYES_PREDICTIONS,
    BAYES_NESTED_METRICS,
    BAYES_FINAL_HISTORY,
    RECOMMENDED_JOINT_PARAMETERS,
) = nested_lomo_joint_bayesian_search(
    target=BAYES_TARGET,
    n_trials=BAYES_N_TRIALS,
    n_initial=BAYES_N_INITIAL,
    inner_splits=INNER_MATERIAL_FOLDS,
    random_states=RANDOM_STATES,
    stability_weight=BAYES_STABILITY_WEIGHT,
)

RECOMMENDED_ESN_PARAMETERS, RECOMMENDED_XGB_PARAMETERS = _split_joint_parameters(
    RECOMMENDED_JOINT_PARAMETERS
)

BAYES_OUTER_STABILITY = pd.DataFrame([{
    "folds": len(BAYES_OUTER_RESULTS),
    "mean_fold_mae": BAYES_OUTER_RESULTS["mae"].mean(),
    "sd_fold_mae": BAYES_OUTER_RESULTS["mae"].std(ddof=1),
    "worst_fold_mae": BAYES_OUTER_RESULTS["mae"].max(),
    "mean_fold_rmse": BAYES_OUTER_RESULTS["rmse"].mean(),
    "sd_fold_rmse": BAYES_OUTER_RESULTS["rmse"].std(ddof=1),
    "worst_fold_rmse": BAYES_OUTER_RESULTS["rmse"].max(),
    "mean_fold_nrmse_training_range": BAYES_OUTER_RESULTS["nrmse_training_range"].mean(),
    "sd_fold_nrmse_training_range": BAYES_OUTER_RESULTS["nrmse_training_range"].std(ddof=1),
    "worst_fold_nrmse_training_range": BAYES_OUTER_RESULTS["nrmse_training_range"].max(),
}])

print("Unbiased nested-LOMO pooled OOF performance:")
display(BAYES_NESTED_METRICS)
print("Valid per-material outer-fold diagnostics and selected joint parameters:")
display(BAYES_OUTER_RESULTS)
print("Across-material stability:")
display(BAYES_OUTER_STABILITY)
print("Final recommended ESN parameters:")
display(pd.Series(RECOMMENDED_ESN_PARAMETERS))
print("Final recommended XGBoost parameters:")
display(pd.Series(RECOMMENDED_XGB_PARAMETERS))

# Save all expensive results so routine Notebook 3B never reruns this search.
BAYES_SEARCH_HISTORY.to_csv(RESULTS_DIR / f"{RESULT_STEM}_joint_search_history.csv", index=False)
BAYES_OUTER_RESULTS.to_csv(RESULTS_DIR / f"{RESULT_STEM}_outer_fold_metrics.csv", index=False)
BAYES_PREDICTIONS.to_csv(RESULTS_DIR / f"{RESULT_STEM}_nested_oof_predictions.csv", index=False)
BAYES_NESTED_METRICS.to_csv(RESULTS_DIR / f"{RESULT_STEM}_pooled_oof_metrics.csv", index=False)
BAYES_OUTER_STABILITY.to_csv(RESULTS_DIR / f"{RESULT_STEM}_fold_stability.csv", index=False)
BAYES_FINAL_HISTORY.to_csv(RESULTS_DIR / f"{RESULT_STEM}_final_joint_search_history.csv", index=False)

parameter_payload = {
    "source": "final all-material joint ESN-XGBoost Bayesian search after nested LOMO evaluation",
    "file_title": FILE_TITLE,
    "target": BAYES_TARGET,
    "analysis_window": [float(value) for value in ANALYSIS_WINDOW],
    "summary_features": [
        "mean", "std", "range", "net_change", "slope", "absolute_area",
        "time_of_max_absolute", "skewness", "excess_kurtosis",
    ],
    "reservoir_seeds": [int(value) for value in RANDOM_STATES],
    "esn_parameters": {
        key: (int(value) if key in {"res_size", "washout"} else float(value))
        for key, value in RECOMMENDED_ESN_PARAMETERS.items()
    },
    "xgb_parameters": {
        key: (int(value) if key in {"n_estimators", "max_depth"} else float(value))
        for key, value in RECOMMENDED_XGB_PARAMETERS.items()
    },
    "bayesian_search": {
        "type": "joint_esn_xgboost_gaussian_process_expected_improvement",
        "n_trials": int(BAYES_N_TRIALS),
        "n_initial": int(BAYES_N_INITIAL),
        "inner_material_folds": int(INNER_MATERIAL_FOLDS),
        "stability_weight": float(BAYES_STABILITY_WEIGHT),
        "search_space": {
            key: [kind, float(low), float(high)]
            for key, (kind, low, high) in BAYES_SPACE.items()
        },
    },
}
with PARAMETER_FILE.open("w") as file:
    json.dump(parameter_payload, file, indent=2)

print("Saved joint fixed-parameter configuration to:", PARAMETER_FILE)
# Out:
# Outer fold 1/14: held out aluminum
#   Joint Bayesian trial 01/50: J=0.3822
#   Joint Bayesian trial 02/50: J=0.5854
#   Joint Bayesian trial 03/50: J=0.6834
#   Joint Bayesian trial 04/50: J=0.8978
#   Joint Bayesian trial 05/50: J=0.7850
#   Joint Bayesian trial 06/50: J=0.6559
#   Joint Bayesian trial 07/50: J=0.5533
#   Joint Bayesian trial 08/50: J=0.2975
#   Joint Bayesian trial 09/50: J=0.5730
#   Joint Bayesian trial 10/50: J=0.3530
#   Joint Bayesian trial 11/50: J=0.6295
#   Joint Bayesian trial 12/50: J=0.3097
#   Joint Bayesian trial 13/50: J=0.4661
#   Joint Bayesian trial 14/50: J=0.7566
#   Joint Bayesian trial 15/50: J=0.5383
#   Joint Bayesian trial 16/50: J=0.2855
#   Joint Bayesian trial 17/50: J=0.7433
#   Joint Bayesian trial 18/50: J=0.3518
#   Joint Bayesian trial 19/50: J=0.5360
#   Joint Bayesian trial 20/50: J=0.3074
#   Joint Bayesian trial 21/50: J=0.2935
#   Joint Bayesian trial 22/50: J=0.3717
#   Joint Bayesian trial 23/50: J=0.3957
#   Joint Bayesian trial 24/50: J=0.2654
#   Joint Bayesian trial 25/50: J=0.7647
#   Joint Bayesian trial 26/50: J=0.5727
#   Joint Bayesian trial 27/50: J=0.4015
#   Joint Bayesian trial 28/50: J=0.4144
#   Joint Bayesian trial 29/50: J=0.3145
#   Joint Bayesian trial 30/50: J=0.5815
#   Joint Bayesian trial 31/50: J=0.5502
#   Joint Bayesian trial 32/50: J=1.4120
#   Joint Bayesian trial 33/50: J=0.3786
#   Joint Bayesian trial 34/50: J=0.5528
#   Joint Bayesian trial 35/50: J=0.4013
#   Joint Bayesian trial 36/50: J=0.3029
#   Joint Bayesian trial 37/50: J=0.4062
#   Joint Bayesian trial 38/50: J=0.3240
#   Joint Bayesian trial 39/50: J=0.4793
#   Joint Bayesian trial 40/50: J=0.2879
#   Joint Bayesian trial 41/50: J=0.4574
#   Joint Bayesian trial 42/50: J=0.5680
#   Joint Bayesian trial 43/50: J=0.2941
#   Joint Bayesian trial 44/50: J=0.5889
#   Joint Bayesian trial 45/50: J=0.4324
#   Joint Bayesian trial 46/50: J=0.6497
#   Joint Bayesian trial 47/50: J=0.4835
#   Joint Bayesian trial 48/50: J=0.6288
#   Joint Bayesian trial 49/50: J=0.6644
#   Joint Bayesian trial 50/50: J=0.4113
# Outer fold 2/14: held out bismuth
#   Joint Bayesian trial 01/50: J=0.6861
#   Joint Bayesian trial 02/50: J=0.4018
#   Joint Bayesian trial 03/50: J=1.2699
#   Joint Bayesian trial 04/50: J=1.7038
#   Joint Bayesian trial 05/50: J=1.0323
#   Joint Bayesian trial 06/50: J=0.8207
#   Joint Bayesian trial 07/50: J=0.2857
#   Joint Bayesian trial 08/50: J=0.8780
#   Joint Bayesian trial 09/50: J=0.5863
#   Joint Bayesian trial 10/50: J=1.2820
#   Joint Bayesian trial 11/50: J=1.0399
#   Joint Bayesian trial 12/50: J=1.0928
#   Joint Bayesian trial 13/50: J=0.5467
#   Joint Bayesian trial 14/50: J=0.3865
#   Joint Bayesian trial 15/50: J=1.3841
#   Joint Bayesian trial 16/50: J=0.5738
#   Joint Bayesian trial 17/50: J=0.4956
#   Joint Bayesian trial 18/50: J=0.3724
#   Joint Bayesian trial 19/50: J=0.6098
#   Joint Bayesian trial 20/50: J=0.4465
#   Joint Bayesian trial 21/50: J=0.6125
#   Joint Bayesian trial 22/50: J=0.7485
#   Joint Bayesian trial 23/50: J=0.3922
#   Joint Bayesian trial 24/50: J=0.5651
#   Joint Bayesian trial 25/50: J=0.5166
#   Joint Bayesian trial 26/50: J=0.3714
#   Joint Bayesian trial 27/50: J=0.6550
#   Joint Bayesian trial 28/50: J=0.5310
#   Joint Bayesian trial 29/50: J=1.3124
#   Joint Bayesian trial 30/50: J=0.7518
#   Joint Bayesian trial 31/50: J=0.2975
#   Joint Bayesian trial 32/50: J=1.0640
#   Joint Bayesian trial 33/50: J=0.5142
#   Joint Bayesian trial 34/50: J=1.2147
#   Joint Bayesian trial 35/50: J=0.7695
#   Joint Bayesian trial 36/50: J=0.4617
#   Joint Bayesian trial 37/50: J=0.6119
#   Joint Bayesian trial 38/50: J=0.3747
#   Joint Bayesian trial 39/50: J=0.6051
#   Joint Bayesian trial 40/50: J=0.8507
#   Joint Bayesian trial 41/50: J=0.5398
#   Joint Bayesian trial 42/50: J=0.4983
#   Joint Bayesian trial 43/50: J=0.3473
#   Joint Bayesian trial 44/50: J=0.4866
#   Joint Bayesian trial 45/50: J=0.4183
#   Joint Bayesian trial 46/50: J=0.4413
#   Joint Bayesian trial 47/50: J=0.4730
#   Joint Bayesian trial 48/50: J=0.6449
#   Joint Bayesian trial 49/50: J=0.4431
#   Joint Bayesian trial 50/50: J=0.4069
# Outer fold 3/14: held out cement
#   Joint Bayesian trial 01/50: J=0.2110
#   Joint Bayesian trial 02/50: J=0.3541
#   Joint Bayesian trial 03/50: J=0.2535
#   Joint Bayesian trial 04/50: J=0.4251
#   Joint Bayesian trial 05/50: J=0.3206
#   Joint Bayesian trial 06/50: J=0.2880
#   Joint Bayesian trial 07/50: J=0.2705
#   Joint Bayesian trial 08/50: J=0.3082
#   Joint Bayesian trial 09/50: J=0.4016
#   Joint Bayesian trial 10/50: J=0.2556
#   Joint Bayesian trial 11/50: J=0.2602
#   Joint Bayesian trial 12/50: J=0.3274
#   Joint Bayesian trial 13/50: J=0.3514
#   Joint Bayesian trial 14/50: J=0.2598
#   Joint Bayesian trial 15/50: J=0.2376
#   Joint Bayesian trial 16/50: J=0.3746
#   Joint Bayesian trial 17/50: J=0.5054
#   Joint Bayesian trial 18/50: J=0.3476
#   Joint Bayesian trial 19/50: J=0.2704
#   Joint Bayesian trial 20/50: J=0.2857
#   Joint Bayesian trial 21/50: J=0.3712
#   Joint Bayesian trial 22/50: J=0.2578
#   Joint Bayesian trial 23/50: J=0.2518
#   Joint Bayesian trial 24/50: J=0.2842
#   Joint Bayesian trial 25/50: J=0.3397
#   Joint Bayesian trial 26/50: J=0.4579
#   Joint Bayesian trial 27/50: J=0.3494
#   Joint Bayesian trial 28/50: J=0.2459
#   Joint Bayesian trial 29/50: J=0.2391
#   Joint Bayesian trial 30/50: J=0.3020
#   Joint Bayesian trial 31/50: J=0.2272
#   Joint Bayesian trial 32/50: J=0.2794
#   Joint Bayesian trial 33/50: J=0.2650
#   Joint Bayesian trial 34/50: J=0.2392
#   Joint Bayesian trial 35/50: J=0.2141
#   Joint Bayesian trial 36/50: J=0.2561
#   Joint Bayesian trial 37/50: J=0.4451
#   Joint Bayesian trial 38/50: J=0.2795
#   Joint Bayesian trial 39/50: J=0.2313
#   Joint Bayesian trial 40/50: J=0.2482
#   Joint Bayesian trial 41/50: J=0.3285
#   Joint Bayesian trial 42/50: J=0.2459
#   Joint Bayesian trial 43/50: J=0.2578
#   Joint Bayesian trial 44/50: J=0.2396
#   Joint Bayesian trial 45/50: J=0.2578
#   Joint Bayesian trial 46/50: J=0.2238
#   Joint Bayesian trial 47/50: J=0.3813
#   Joint Bayesian trial 48/50: J=0.3241
#   Joint Bayesian trial 49/50: J=0.2359
#   Joint Bayesian trial 50/50: J=0.2422
# Outer fold 4/14: held out copper
#   Joint Bayesian trial 01/50: J=0.1925
#   Joint Bayesian trial 02/50: J=0.1908
#   Joint Bayesian trial 03/50: J=0.1960
#   Joint Bayesian trial 04/50: J=0.2690
#   Joint Bayesian trial 05/50: J=0.2004
#   Joint Bayesian trial 06/50: J=0.2634
#   Joint Bayesian trial 07/50: J=0.1781
#   Joint Bayesian trial 08/50: J=0.1499
#   Joint Bayesian trial 09/50: J=0.2079
#   Joint Bayesian trial 10/50: J=0.2889
#   Joint Bayesian trial 11/50: J=0.1788
#   Joint Bayesian trial 12/50: J=0.1596
#   Joint Bayesian trial 13/50: J=0.1638
#   Joint Bayesian trial 14/50: J=0.1799
#   Joint Bayesian trial 15/50: J=0.2540
#   Joint Bayesian trial 16/50: J=0.1912
#   Joint Bayesian trial 17/50: J=0.3303
#   Joint Bayesian trial 18/50: J=0.1677
#   Joint Bayesian trial 19/50: J=0.2866
#   Joint Bayesian trial 20/50: J=0.2775
#   Joint Bayesian trial 21/50: J=0.2072
#   Joint Bayesian trial 22/50: J=0.1973
#   Joint Bayesian trial 23/50: J=0.2140
#   Joint Bayesian trial 24/50: J=0.1584
#   Joint Bayesian trial 25/50: J=0.3634
#   Joint Bayesian trial 26/50: J=0.1652
#   Joint Bayesian trial 27/50: J=0.1985
#   Joint Bayesian trial 28/50: J=0.1584
#   Joint Bayesian trial 29/50: J=0.1902
#   Joint Bayesian trial 30/50: J=0.1811
#   Joint Bayesian trial 31/50: J=0.2974
#   Joint Bayesian trial 32/50: J=0.3221
#   Joint Bayesian trial 33/50: J=0.1923
#   Joint Bayesian trial 34/50: J=0.2554
#   Joint Bayesian trial 35/50: J=0.1757
#   Joint Bayesian trial 36/50: J=0.3011
#   Joint Bayesian trial 37/50: J=0.1622
#   Joint Bayesian trial 38/50: J=0.1685
#   Joint Bayesian trial 39/50: J=0.1709
#   Joint Bayesian trial 40/50: J=0.1793
#   Joint Bayesian trial 41/50: J=0.1880
#   Joint Bayesian trial 42/50: J=0.2283
#   Joint Bayesian trial 43/50: J=0.1797
#   Joint Bayesian trial 44/50: J=0.1853
#   Joint Bayesian trial 45/50: J=0.1856
#   Joint Bayesian trial 46/50: J=0.1740
#   Joint Bayesian trial 47/50: J=0.1716
#   Joint Bayesian trial 48/50: J=0.1947
#   Joint Bayesian trial 49/50: J=0.2754
#   Joint Bayesian trial 50/50: J=0.1802
# Outer fold 5/14: held out cork
#   Joint Bayesian trial 01/50: J=0.2928
#   Joint Bayesian trial 02/50: J=0.3321
#   Joint Bayesian trial 03/50: J=0.3437
#   Joint Bayesian trial 04/50: J=0.3430
#   Joint Bayesian trial 05/50: J=0.2659
#   Joint Bayesian trial 06/50: J=0.2504
#   Joint Bayesian trial 07/50: J=0.2601
#   Joint Bayesian trial 08/50: J=0.2634
#   Joint Bayesian trial 09/50: J=0.2751
#   Joint Bayesian trial 10/50: J=0.2907
#   Joint Bayesian trial 11/50: J=0.2762
#   Joint Bayesian trial 12/50: J=0.3460
#   Joint Bayesian trial 13/50: J=0.2596
#   Joint Bayesian trial 14/50: J=0.2917
#   Joint Bayesian trial 15/50: J=0.3042
#   Joint Bayesian trial 16/50: J=0.2780
#   Joint Bayesian trial 17/50: J=0.2743
#   Joint Bayesian trial 18/50: J=0.2943
#   Joint Bayesian trial 19/50: J=0.2770
#   Joint Bayesian trial 20/50: J=0.2687
#   Joint Bayesian trial 21/50: J=0.2815
#   Joint Bayesian trial 22/50: J=0.3249
#   Joint Bayesian trial 23/50: J=0.4094
#   Joint Bayesian trial 24/50: J=0.3300
#   Joint Bayesian trial 25/50: J=0.3073
#   Joint Bayesian trial 26/50: J=0.4515
#   Joint Bayesian trial 27/50: J=0.2946
#   Joint Bayesian trial 28/50: J=0.2661
#   Joint Bayesian trial 29/50: J=0.2899
#   Joint Bayesian trial 30/50: J=0.4112
#   Joint Bayesian trial 31/50: J=0.3080
#   Joint Bayesian trial 32/50: J=0.3189
#   Joint Bayesian trial 33/50: J=0.2806
#   Joint Bayesian trial 34/50: J=0.3547
#   Joint Bayesian trial 35/50: J=0.3053
#   Joint Bayesian trial 36/50: J=0.2802
#   Joint Bayesian trial 37/50: J=0.3154
#   Joint Bayesian trial 38/50: J=0.2465
#   Joint Bayesian trial 39/50: J=0.3350
#   Joint Bayesian trial 40/50: J=0.2883
#   Joint Bayesian trial 41/50: J=0.4671
#   Joint Bayesian trial 42/50: J=0.2862
#   Joint Bayesian trial 43/50: J=0.3178
#   Joint Bayesian trial 44/50: J=0.2827
#   Joint Bayesian trial 45/50: J=0.2584
#   Joint Bayesian trial 46/50: J=0.2942
#   Joint Bayesian trial 47/50: J=0.2816
#   Joint Bayesian trial 48/50: J=0.2790
#   Joint Bayesian trial 49/50: J=0.2771
#   Joint Bayesian trial 50/50: J=0.3231
# Outer fold 6/14: held out graphite
#   Joint Bayesian trial 01/50: J=0.3044
#   Joint Bayesian trial 02/50: J=0.2664
#   Joint Bayesian trial 03/50: J=0.2885
#   Joint Bayesian trial 04/50: J=0.2783
#   Joint Bayesian trial 05/50: J=0.2539
#   Joint Bayesian trial 06/50: J=0.3075
#   Joint Bayesian trial 07/50: J=0.2941
#   Joint Bayesian trial 08/50: J=0.2510
#   Joint Bayesian trial 09/50: J=0.2855
#   Joint Bayesian trial 10/50: J=0.2881
#   Joint Bayesian trial 11/50: J=0.2759
#   Joint Bayesian trial 12/50: J=0.4602
#   Joint Bayesian trial 13/50: J=0.2595
#   Joint Bayesian trial 14/50: J=0.3747
#   Joint Bayesian trial 15/50: J=0.2596
#   Joint Bayesian trial 16/50: J=0.3266
#   Joint Bayesian trial 17/50: J=0.2768
#   Joint Bayesian trial 18/50: J=0.3817
#   Joint Bayesian trial 19/50: J=0.3076
#   Joint Bayesian trial 20/50: J=0.3167
#   Joint Bayesian trial 21/50: J=0.3446
#   Joint Bayesian trial 22/50: J=0.3061
#   Joint Bayesian trial 23/50: J=0.2467
#   Joint Bayesian trial 24/50: J=0.2800
#   Joint Bayesian trial 25/50: J=0.2749
#   Joint Bayesian trial 26/50: J=0.3647
#   Joint Bayesian trial 27/50: J=0.2964
#   Joint Bayesian trial 28/50: J=0.2750
#   Joint Bayesian trial 29/50: J=0.4479
#   Joint Bayesian trial 30/50: J=0.2870
#   Joint Bayesian trial 31/50: J=0.3005
#   Joint Bayesian trial 32/50: J=0.2568
#   Joint Bayesian trial 33/50: J=0.2709
#   Joint Bayesian trial 34/50: J=0.3161
#   Joint Bayesian trial 35/50: J=0.2678
#   Joint Bayesian trial 36/50: J=0.3124
#   Joint Bayesian trial 37/50: J=0.2884
#   Joint Bayesian trial 38/50: J=0.2969
#   Joint Bayesian trial 39/50: J=0.4348
#   Joint Bayesian trial 40/50: J=0.2960
#   Joint Bayesian trial 41/50: J=0.2603
#   Joint Bayesian trial 42/50: J=0.2887
#   Joint Bayesian trial 43/50: J=0.2778
#   Joint Bayesian trial 44/50: J=0.2763
#   Joint Bayesian trial 45/50: J=0.5177
#   Joint Bayesian trial 46/50: J=0.2732
#   Joint Bayesian trial 47/50: J=0.3062
#   Joint Bayesian trial 48/50: J=0.2868
#   Joint Bayesian trial 49/50: J=0.3623
#   Joint Bayesian trial 50/50: J=0.2958
# Outer fold 7/14: held out gypsum
#   Joint Bayesian trial 01/50: J=0.2963
#   Joint Bayesian trial 02/50: J=0.2805
#   Joint Bayesian trial 03/50: J=0.2530
#   Joint Bayesian trial 04/50: J=0.2813
#   Joint Bayesian trial 05/50: J=0.3040
#   Joint Bayesian trial 06/50: J=0.2930
#   Joint Bayesian trial 07/50: J=0.3075
#   Joint Bayesian trial 08/50: J=0.2553
#   Joint Bayesian trial 09/50: J=0.3429
#   Joint Bayesian trial 10/50: J=0.2726
#   Joint Bayesian trial 11/50: J=0.2975
#   Joint Bayesian trial 12/50: J=0.2775
#   Joint Bayesian trial 13/50: J=0.2915
#   Joint Bayesian trial 14/50: J=0.2909
#   Joint Bayesian trial 15/50: J=0.2634
#   Joint Bayesian trial 16/50: J=0.2574
#   Joint Bayesian trial 17/50: J=0.2800
#   Joint Bayesian trial 18/50: J=0.3059
#   Joint Bayesian trial 19/50: J=0.3011
#   Joint Bayesian trial 20/50: J=0.2770
#   Joint Bayesian trial 21/50: J=0.2592
#   Joint Bayesian trial 22/50: J=0.2941
#   Joint Bayesian trial 23/50: J=0.2996
#   Joint Bayesian trial 24/50: J=0.2672
#   Joint Bayesian trial 25/50: J=0.3563
#   Joint Bayesian trial 26/50: J=0.2479
#   Joint Bayesian trial 27/50: J=0.2810
#   Joint Bayesian trial 28/50: J=0.2770
#   Joint Bayesian trial 29/50: J=0.2665
#   Joint Bayesian trial 30/50: J=0.2828
#   Joint Bayesian trial 31/50: J=0.2754
#   Joint Bayesian trial 32/50: J=0.2580
#   Joint Bayesian trial 33/50: J=0.2553
#   Joint Bayesian trial 34/50: J=0.2870
#   Joint Bayesian trial 35/50: J=0.2843
#   Joint Bayesian trial 36/50: J=0.2706
#   Joint Bayesian trial 37/50: J=0.2921
#   Joint Bayesian trial 38/50: J=0.2598
#   Joint Bayesian trial 39/50: J=0.2804
#   Joint Bayesian trial 40/50: J=0.3227
#   Joint Bayesian trial 41/50: J=0.2672
#   Joint Bayesian trial 42/50: J=0.2955
#   Joint Bayesian trial 43/50: J=0.2740
#   Joint Bayesian trial 44/50: J=0.2656
#   Joint Bayesian trial 45/50: J=0.2818
#   Joint Bayesian trial 46/50: J=0.2853
#   Joint Bayesian trial 47/50: J=0.2501
#   Joint Bayesian trial 48/50: J=0.2786
#   Joint Bayesian trial 49/50: J=0.2837
#   Joint Bayesian trial 50/50: J=0.3149
# Outer fold 8/14: held out iron
#   Joint Bayesian trial 01/50: J=0.6589
#   Joint Bayesian trial 02/50: J=0.5267
#   Joint Bayesian trial 03/50: J=0.5338
#   Joint Bayesian trial 04/50: J=0.5095
#   Joint Bayesian trial 05/50: J=0.8981
#   Joint Bayesian trial 06/50: J=0.6367
#   Joint Bayesian trial 07/50: J=0.4770
#   Joint Bayesian trial 08/50: J=0.6847
#   Joint Bayesian trial 09/50: J=0.4127
#   Joint Bayesian trial 10/50: J=0.5667
#   Joint Bayesian trial 11/50: J=0.4686
#   Joint Bayesian trial 12/50: J=0.9080
#   Joint Bayesian trial 13/50: J=0.7686
#   Joint Bayesian trial 14/50: J=0.5873
#   Joint Bayesian trial 15/50: J=0.5664
#   Joint Bayesian trial 16/50: J=0.7468
#   Joint Bayesian trial 17/50: J=0.6233
#   Joint Bayesian trial 18/50: J=0.5558
#   Joint Bayesian trial 19/50: J=0.3978
#   Joint Bayesian trial 20/50: J=0.5179
#   Joint Bayesian trial 21/50: J=0.5500
#   Joint Bayesian trial 22/50: J=0.5290
#   Joint Bayesian trial 23/50: J=0.3189
#   Joint Bayesian trial 24/50: J=0.3169
#   Joint Bayesian trial 25/50: J=0.4821
#   Joint Bayesian trial 26/50: J=0.4477
#   Joint Bayesian trial 27/50: J=0.4611
#   Joint Bayesian trial 28/50: J=0.4056
#   Joint Bayesian trial 29/50: J=0.3264
#   Joint Bayesian trial 30/50: J=0.4299
#   Joint Bayesian trial 31/50: J=0.4674
#   Joint Bayesian trial 32/50: J=0.3742
#   Joint Bayesian trial 33/50: J=0.2865
#   Joint Bayesian trial 34/50: J=0.5123
#   Joint Bayesian trial 35/50: J=0.2973
#   Joint Bayesian trial 36/50: J=0.3536
#   Joint Bayesian trial 37/50: J=0.6711
#   Joint Bayesian trial 38/50: J=0.2865
#   Joint Bayesian trial 39/50: J=0.4393
#   Joint Bayesian trial 40/50: J=0.4198
#   Joint Bayesian trial 41/50: J=0.4946
#   Joint Bayesian trial 42/50: J=0.3691
#   Joint Bayesian trial 43/50: J=0.4757
#   Joint Bayesian trial 44/50: J=0.4178
#   Joint Bayesian trial 45/50: J=0.3809
#   Joint Bayesian trial 46/50: J=0.3696
#   Joint Bayesian trial 47/50: J=0.2730
#   Joint Bayesian trial 48/50: J=0.3372
#   Joint Bayesian trial 49/50: J=0.5555
#   Joint Bayesian trial 50/50: J=0.4323
# Outer fold 9/14: held out nickel
#   Joint Bayesian trial 01/50: J=0.7526
#   Joint Bayesian trial 02/50: J=0.6331
#   Joint Bayesian trial 03/50: J=0.2780
#   Joint Bayesian trial 04/50: J=0.8336
#   Joint Bayesian trial 05/50: J=0.6216
#   Joint Bayesian trial 06/50: J=0.7951
#   Joint Bayesian trial 07/50: J=0.3609
#   Joint Bayesian trial 08/50: J=1.0399
#   Joint Bayesian trial 09/50: J=0.4356
#   Joint Bayesian trial 10/50: J=0.4029
#   Joint Bayesian trial 11/50: J=0.7279
#   Joint Bayesian trial 12/50: J=0.4465
#   Joint Bayesian trial 13/50: J=0.2935
#   Joint Bayesian trial 14/50: J=0.3309
#   Joint Bayesian trial 15/50: J=0.5574
#   Joint Bayesian trial 16/50: J=0.3754
#   Joint Bayesian trial 17/50: J=0.3597
#   Joint Bayesian trial 18/50: J=0.3935
#   Joint Bayesian trial 19/50: J=0.2789
#   Joint Bayesian trial 20/50: J=0.3722
#   Joint Bayesian trial 21/50: J=0.3102
#   Joint Bayesian trial 22/50: J=0.4963
#   Joint Bayesian trial 23/50: J=0.3982
#   Joint Bayesian trial 24/50: J=0.4087
#   Joint Bayesian trial 25/50: J=1.2693
#   Joint Bayesian trial 26/50: J=0.3515
#   Joint Bayesian trial 27/50: J=0.5713
#   Joint Bayesian trial 28/50: J=0.6514
#   Joint Bayesian trial 29/50: J=0.4056
#   Joint Bayesian trial 30/50: J=0.3058
#   Joint Bayesian trial 31/50: J=0.2727
#   Joint Bayesian trial 32/50: J=0.3651
#   Joint Bayesian trial 33/50: J=0.3308
#   Joint Bayesian trial 34/50: J=0.4535
#   Joint Bayesian trial 35/50: J=0.7295
#   Joint Bayesian trial 36/50: J=0.4011
#   Joint Bayesian trial 37/50: J=0.2405
#   Joint Bayesian trial 38/50: J=0.7034
#   Joint Bayesian trial 39/50: J=0.5565
#   Joint Bayesian trial 40/50: J=0.4058
#   Joint Bayesian trial 41/50: J=0.5499
#   Joint Bayesian trial 42/50: J=0.5242
#   Joint Bayesian trial 43/50: J=0.5074
#   Joint Bayesian trial 44/50: J=0.4621
#   Joint Bayesian trial 45/50: J=0.3947
#   Joint Bayesian trial 46/50: J=0.5648
#   Joint Bayesian trial 47/50: J=0.4019
#   Joint Bayesian trial 48/50: J=0.6250
#   Joint Bayesian trial 49/50: J=0.4457
#   Joint Bayesian trial 50/50: J=0.3564
# Outer fold 10/14: held out pdms
#   Joint Bayesian trial 01/50: J=0.4019
#   Joint Bayesian trial 02/50: J=0.4362
#   Joint Bayesian trial 03/50: J=0.2652
#   Joint Bayesian trial 04/50: J=0.6810
#   Joint Bayesian trial 05/50: J=0.2551
#   Joint Bayesian trial 06/50: J=0.2941
#   Joint Bayesian trial 07/50: J=0.4407
#   Joint Bayesian trial 08/50: J=0.8433
#   Joint Bayesian trial 09/50: J=0.4034
#   Joint Bayesian trial 10/50: J=0.3289
#   Joint Bayesian trial 11/50: J=0.7687
#   Joint Bayesian trial 12/50: J=0.3037
#   Joint Bayesian trial 13/50: J=0.3056
#   Joint Bayesian trial 14/50: J=0.3842
#   Joint Bayesian trial 15/50: J=0.4762
#   Joint Bayesian trial 16/50: J=0.3066
#   Joint Bayesian trial 17/50: J=1.1665
#   Joint Bayesian trial 18/50: J=0.3294
#   Joint Bayesian trial 19/50: J=1.1540
#   Joint Bayesian trial 20/50: J=0.2819
#   Joint Bayesian trial 21/50: J=0.6332
#   Joint Bayesian trial 22/50: J=0.4189
#   Joint Bayesian trial 23/50: J=0.4575
#   Joint Bayesian trial 24/50: J=0.7271
#   Joint Bayesian trial 25/50: J=0.3998
#   Joint Bayesian trial 26/50: J=0.4390
#   Joint Bayesian trial 27/50: J=0.7058
#   Joint Bayesian trial 28/50: J=0.2400
#   Joint Bayesian trial 29/50: J=0.3090
#   Joint Bayesian trial 30/50: J=0.3056
#   Joint Bayesian trial 31/50: J=0.2734
#   Joint Bayesian trial 32/50: J=0.6962
#   Joint Bayesian trial 33/50: J=0.4124
#   Joint Bayesian trial 34/50: J=0.3034
#   Joint Bayesian trial 35/50: J=0.2610
#   Joint Bayesian trial 36/50: J=0.3102
#   Joint Bayesian trial 37/50: J=0.2774
#   Joint Bayesian trial 38/50: J=0.2559
#   Joint Bayesian trial 39/50: J=0.2440
#   Joint Bayesian trial 40/50: J=0.2568
#   Joint Bayesian trial 41/50: J=0.2933
#   Joint Bayesian trial 42/50: J=0.2411
#   Joint Bayesian trial 43/50: J=0.2551
#   Joint Bayesian trial 44/50: J=0.6625
#   Joint Bayesian trial 45/50: J=0.5129
#   Joint Bayesian trial 46/50: J=0.3593
#   Joint Bayesian trial 47/50: J=0.5781
#   Joint Bayesian trial 48/50: J=0.6472
#   Joint Bayesian trial 49/50: J=0.2765
#   Joint Bayesian trial 50/50: J=0.4365
# Outer fold 11/14: held out ps_foam
#   Joint Bayesian trial 01/50: J=0.6002
#   Joint Bayesian trial 02/50: J=0.4809
#   Joint Bayesian trial 03/50: J=0.2661
#   Joint Bayesian trial 04/50: J=0.6775
#   Joint Bayesian trial 05/50: J=0.7304
#   Joint Bayesian trial 06/50: J=0.5222
#   Joint Bayesian trial 07/50: J=0.5023
#   Joint Bayesian trial 08/50: J=0.7466
#   Joint Bayesian trial 09/50: J=0.4700
#   Joint Bayesian trial 10/50: J=0.4619
#   Joint Bayesian trial 11/50: J=1.4183
#   Joint Bayesian trial 12/50: J=0.3886
#   Joint Bayesian trial 13/50: J=0.3423
#   Joint Bayesian trial 14/50: J=0.4568
#   Joint Bayesian trial 15/50: J=0.5583
#   Joint Bayesian trial 16/50: J=0.3241
#   Joint Bayesian trial 17/50: J=0.2734
#   Joint Bayesian trial 18/50: J=0.3035
#   Joint Bayesian trial 19/50: J=0.4155
#   Joint Bayesian trial 20/50: J=0.2707
#   Joint Bayesian trial 21/50: J=0.3100
#   Joint Bayesian trial 22/50: J=0.3369
#   Joint Bayesian trial 23/50: J=0.6691
#   Joint Bayesian trial 24/50: J=0.3532
#   Joint Bayesian trial 25/50: J=0.3375
#   Joint Bayesian trial 26/50: J=0.6219
#   Joint Bayesian trial 27/50: J=0.7978
#   Joint Bayesian trial 28/50: J=1.3321
#   Joint Bayesian trial 29/50: J=0.2905
#   Joint Bayesian trial 30/50: J=0.4332
#   Joint Bayesian trial 31/50: J=0.3169
#   Joint Bayesian trial 32/50: J=0.3160
#   Joint Bayesian trial 33/50: J=0.5569
#   Joint Bayesian trial 34/50: J=0.6040
#   Joint Bayesian trial 35/50: J=0.3085
#   Joint Bayesian trial 36/50: J=0.4348
#   Joint Bayesian trial 37/50: J=0.4372
#   Joint Bayesian trial 38/50: J=0.3091
#   Joint Bayesian trial 39/50: J=0.3190
#   Joint Bayesian trial 40/50: J=0.3555
#   Joint Bayesian trial 41/50: J=0.8230
#   Joint Bayesian trial 42/50: J=0.4385
#   Joint Bayesian trial 43/50: J=0.8530
#   Joint Bayesian trial 44/50: J=0.3498
#   Joint Bayesian trial 45/50: J=0.8844
#   Joint Bayesian trial 46/50: J=0.3185
#   Joint Bayesian trial 47/50: J=0.8303
#   Joint Bayesian trial 48/50: J=0.5187
#   Joint Bayesian trial 49/50: J=0.4727
#   Joint Bayesian trial 50/50: J=0.6140
# Outer fold 12/14: held out pu_foam
#   Joint Bayesian trial 01/50: J=0.5520
#   Joint Bayesian trial 02/50: J=0.8903
#   Joint Bayesian trial 03/50: J=0.5238
#   Joint Bayesian trial 04/50: J=0.3624
#   Joint Bayesian trial 05/50: J=0.3783
#   Joint Bayesian trial 06/50: J=0.5378
#   Joint Bayesian trial 07/50: J=0.4971
#   Joint Bayesian trial 08/50: J=0.9994
#   Joint Bayesian trial 09/50: J=0.6060
#   Joint Bayesian trial 10/50: J=0.5956
#   Joint Bayesian trial 11/50: J=0.8079
#   Joint Bayesian trial 12/50: J=0.3466
#   Joint Bayesian trial 13/50: J=0.4598
#   Joint Bayesian trial 14/50: J=0.7152
#   Joint Bayesian trial 15/50: J=0.9100
#   Joint Bayesian trial 16/50: J=0.4567
#   Joint Bayesian trial 17/50: J=0.2883
#   Joint Bayesian trial 18/50: J=0.3392
#   Joint Bayesian trial 19/50: J=0.4137
#   Joint Bayesian trial 20/50: J=0.4166
#   Joint Bayesian trial 21/50: J=0.8939
#   Joint Bayesian trial 22/50: J=0.3463
#   Joint Bayesian trial 23/50: J=0.6188
#   Joint Bayesian trial 24/50: J=0.4575
#   Joint Bayesian trial 25/50: J=0.7169
#   Joint Bayesian trial 26/50: J=0.4139
#   Joint Bayesian trial 27/50: J=0.3788
#   Joint Bayesian trial 28/50: J=0.2734
#   Joint Bayesian trial 29/50: J=0.8175
#   Joint Bayesian trial 30/50: J=1.0259
#   Joint Bayesian trial 31/50: J=0.4093
#   Joint Bayesian trial 32/50: J=0.4460
#   Joint Bayesian trial 33/50: J=0.4716
#   Joint Bayesian trial 34/50: J=0.9079
#   Joint Bayesian trial 35/50: J=0.5595
#   Joint Bayesian trial 36/50: J=0.6413
#   Joint Bayesian trial 37/50: J=0.5944
#   Joint Bayesian trial 38/50: J=0.4739
#   Joint Bayesian trial 39/50: J=0.6459
#   Joint Bayesian trial 40/50: J=0.5599
#   Joint Bayesian trial 41/50: J=0.5866
#   Joint Bayesian trial 42/50: J=0.3959
#   Joint Bayesian trial 43/50: J=0.5713
#   Joint Bayesian trial 44/50: J=0.3282
#   Joint Bayesian trial 45/50: J=0.2610
#   Joint Bayesian trial 46/50: J=0.4021
#   Joint Bayesian trial 47/50: J=0.2992
#   Joint Bayesian trial 48/50: J=0.3521
#   Joint Bayesian trial 49/50: J=0.6385
#   Joint Bayesian trial 50/50: J=0.8746
# Outer fold 13/14: held out titanium
#   Joint Bayesian trial 01/50: J=0.3304
#   Joint Bayesian trial 02/50: J=0.5787
#   Joint Bayesian trial 03/50: J=0.9901
#   Joint Bayesian trial 04/50: J=0.4682
#   Joint Bayesian trial 05/50: J=0.3904
#   Joint Bayesian trial 06/50: J=0.9941
#   Joint Bayesian trial 07/50: J=1.1491
#   Joint Bayesian trial 08/50: J=0.5230
#   Joint Bayesian trial 09/50: J=0.4004
#   Joint Bayesian trial 10/50: J=0.6506
#   Joint Bayesian trial 11/50: J=0.5371
#   Joint Bayesian trial 12/50: J=0.5812
#   Joint Bayesian trial 13/50: J=0.4894
#   Joint Bayesian trial 14/50: J=0.5431
#   Joint Bayesian trial 15/50: J=1.3336
#   Joint Bayesian trial 16/50: J=0.6035
#   Joint Bayesian trial 17/50: J=0.5839
#   Joint Bayesian trial 18/50: J=0.2812
#   Joint Bayesian trial 19/50: J=0.4874
#   Joint Bayesian trial 20/50: J=0.6343
#   Joint Bayesian trial 21/50: J=0.3795
#   Joint Bayesian trial 22/50: J=0.3275
#   Joint Bayesian trial 23/50: J=0.5034
#   Joint Bayesian trial 24/50: J=0.5238
#   Joint Bayesian trial 25/50: J=0.6394
#   Joint Bayesian trial 26/50: J=0.4706
#   Joint Bayesian trial 27/50: J=0.4482
#   Joint Bayesian trial 28/50: J=0.3760
#   Joint Bayesian trial 29/50: J=0.5581
#   Joint Bayesian trial 30/50: J=0.4481
#   Joint Bayesian trial 31/50: J=0.5023
#   Joint Bayesian trial 32/50: J=0.3584
#   Joint Bayesian trial 33/50: J=0.6143
#   Joint Bayesian trial 34/50: J=0.6498
#   Joint Bayesian trial 35/50: J=0.4527
#   Joint Bayesian trial 36/50: J=0.3838
#   Joint Bayesian trial 37/50: J=0.5623
#   Joint Bayesian trial 38/50: J=0.3637
#   Joint Bayesian trial 39/50: J=0.6100
#   Joint Bayesian trial 40/50: J=0.5976
#   Joint Bayesian trial 41/50: J=0.4128
#   Joint Bayesian trial 42/50: J=0.7079
#   Joint Bayesian trial 43/50: J=0.5187
#   Joint Bayesian trial 44/50: J=0.3343
#   Joint Bayesian trial 45/50: J=0.6171
#   Joint Bayesian trial 46/50: J=0.4068
#   Joint Bayesian trial 47/50: J=0.4518
#   Joint Bayesian trial 48/50: J=0.7519
#   Joint Bayesian trial 49/50: J=0.5604
#   Joint Bayesian trial 50/50: J=0.4297
# Outer fold 14/14: held out wood
#   Joint Bayesian trial 01/50: J=0.6268
#   Joint Bayesian trial 02/50: J=0.3360
#   Joint Bayesian trial 03/50: J=0.5171
#   Joint Bayesian trial 04/50: J=0.8199
#   Joint Bayesian trial 05/50: J=0.4136
#   Joint Bayesian trial 06/50: J=0.2340
#   Joint Bayesian trial 07/50: J=0.2618
#   Joint Bayesian trial 08/50: J=0.9058
#   Joint Bayesian trial 09/50: J=0.3300
#   Joint Bayesian trial 10/50: J=0.7310
#   Joint Bayesian trial 11/50: J=0.7355
#   Joint Bayesian trial 12/50: J=0.5206
#   Joint Bayesian trial 13/50: J=0.4209
#   Joint Bayesian trial 14/50: J=1.1633
#   Joint Bayesian trial 15/50: J=0.5763
#   Joint Bayesian trial 16/50: J=0.2961
#   Joint Bayesian trial 17/50: J=0.2697
#   Joint Bayesian trial 18/50: J=0.4181
#   Joint Bayesian trial 19/50: J=0.4538
#   Joint Bayesian trial 20/50: J=0.2452
#   Joint Bayesian trial 21/50: J=0.3094
#   Joint Bayesian trial 22/50: J=0.3074
#   Joint Bayesian trial 23/50: J=0.5029
#   Joint Bayesian trial 24/50: J=0.9973
#   Joint Bayesian trial 25/50: J=0.5230
#   Joint Bayesian trial 26/50: J=0.3226
#   Joint Bayesian trial 27/50: J=0.3608
#   Joint Bayesian trial 28/50: J=0.7309
#   Joint Bayesian trial 29/50: J=0.3766
#   Joint Bayesian trial 30/50: J=0.2802
#   Joint Bayesian trial 31/50: J=0.3649
#   Joint Bayesian trial 32/50: J=0.6864
#   Joint Bayesian trial 33/50: J=0.2188
#   Joint Bayesian trial 34/50: J=0.2434
#   Joint Bayesian trial 35/50: J=0.2761
#   Joint Bayesian trial 36/50: J=0.2422
#   Joint Bayesian trial 37/50: J=0.3054
#   Joint Bayesian trial 38/50: J=0.2313
#   Joint Bayesian trial 39/50: J=0.2637
#   Joint Bayesian trial 40/50: J=0.2882
#   Joint Bayesian trial 41/50: J=0.3149
#   Joint Bayesian trial 42/50: J=0.2500
#   Joint Bayesian trial 43/50: J=0.3774
#   Joint Bayesian trial 44/50: J=0.3282
#   Joint Bayesian trial 45/50: J=0.2268
#   Joint Bayesian trial 46/50: J=0.3887
#   Joint Bayesian trial 47/50: J=0.2308
#   Joint Bayesian trial 48/50: J=0.2575
#   Joint Bayesian trial 49/50: J=0.2555
#   Joint Bayesian trial 50/50: J=0.2511
# Final joint Bayesian search on all materials for deployment parameters
#   Joint Bayesian trial 01/50: J=0.3616
#   Joint Bayesian trial 02/50: J=0.3532
#   Joint Bayesian trial 03/50: J=0.4827
#   Joint Bayesian trial 04/50: J=0.6615
#   Joint Bayesian trial 05/50: J=0.6324
#   Joint Bayesian trial 06/50: J=0.6703
#   Joint Bayesian trial 07/50: J=0.4696
#   Joint Bayesian trial 08/50: J=0.5474
#   Joint Bayesian trial 09/50: J=1.3805
#   Joint Bayesian trial 10/50: J=0.3609
#   Joint Bayesian trial 11/50: J=0.5723
#   Joint Bayesian trial 12/50: J=0.5273
#   Joint Bayesian trial 13/50: J=0.6906
#   Joint Bayesian trial 14/50: J=0.2943
#   Joint Bayesian trial 15/50: J=0.4893
#   Joint Bayesian trial 16/50: J=0.3329
#   Joint Bayesian trial 17/50: J=0.7355
#   Joint Bayesian trial 18/50: J=0.4816
#   Joint Bayesian trial 19/50: J=0.4777
#   Joint Bayesian trial 20/50: J=0.3114
#   Joint Bayesian trial 21/50: J=0.2849
#   Joint Bayesian trial 22/50: J=0.5177
#   Joint Bayesian trial 23/50: J=0.3982
#   Joint Bayesian trial 24/50: J=1.0369
#   Joint Bayesian trial 25/50: J=0.3463
#   Joint Bayesian trial 26/50: J=0.6923
#   Joint Bayesian trial 27/50: J=0.5673
#   Joint Bayesian trial 28/50: J=0.2539
#   Joint Bayesian trial 29/50: J=0.4057
#   Joint Bayesian trial 30/50: J=0.3196
#   Joint Bayesian trial 31/50: J=0.4831
#   Joint Bayesian trial 32/50: J=0.3731
#   Joint Bayesian trial 33/50: J=0.2633
#   Joint Bayesian trial 34/50: J=0.3671
#   Joint Bayesian trial 35/50: J=0.3916
#   Joint Bayesian trial 36/50: J=0.3511
#   Joint Bayesian trial 37/50: J=0.4316
#   Joint Bayesian trial 38/50: J=0.5134
#   Joint Bayesian trial 39/50: J=0.2433
#   Joint Bayesian trial 40/50: J=0.2295
#   Joint Bayesian trial 41/50: J=0.2575
#   Joint Bayesian trial 42/50: J=0.5641
#   Joint Bayesian trial 43/50: J=0.3828
#   Joint Bayesian trial 44/50: J=0.2470
#   Joint Bayesian trial 45/50: J=0.7201
#   Joint Bayesian trial 46/50: J=0.5325
#   Joint Bayesian trial 47/50: J=0.5194
#   Joint Bayesian trial 48/50: J=0.8644
#   Joint Bayesian trial 49/50: J=0.5866
#   Joint Bayesian trial 50/50: J=0.8502
# Unbiased nested-LOMO pooled OOF performance:
#   target                                protocol  n_bayesian_trials  \
# 0    eff  nested_lomo_joint_bayesian_esn_xgboost                 50
#
#   random_states   n         mae         rmse  nrmse_range        r2  \
# 0  (42, 43, 44)  84  3598.89765  6960.851605     0.187331  0.614297
#
#    median_ape_pct
# 0       39.975484
# Valid per-material outer-fold diagnostics and selected joint parameters:
#     outer_fold held_out_material  res_size  leak_rate  input_magnitude  \
# 0            1          aluminum        78   0.442069         0.868126
# 1            2           bismuth        33   0.099164         0.853517
# 2            3            cement        66   0.084571         0.978647
# 3            4            copper        31   0.653831         0.576620
# 4            5              cork        30   0.139098         0.376591
# 5            6          graphite        59   0.091556         0.332237
# 6            7            gypsum        70   0.711204         0.460562
# 7            8              iron        56   0.408865         1.834817
# 8            9            nickel        78   0.651496         1.442656
# 9           10              pdms        51   0.346363         1.956699
# 10          11           ps_foam        71   0.443991         1.542218
# 11          12           pu_foam        58   0.854119         0.859517
# 12          13          titanium        46   0.949423         1.287482
# 13          14              wood        55   0.604314         1.948316
#
#     spectral_radius  washout  n_estimators  max_depth  learning_rate  ...  \
# 0          1.449475        4           446          4       0.014409  ...
# 1          1.141351        0           151          4       0.047681  ...
# 2          1.197418        3           239          2       0.019286  ...
# 3          0.689874        1           548          4       0.109359  ...
# 4          1.459828        4           423          2       0.033613  ...
# 5          0.760851        1           313          4       0.138345  ...
# 6          0.595778        4           343          2       0.010958  ...
# 7          0.888874        2           573          1       0.138213  ...
# 8          1.384729        2           561          4       0.020671  ...
# 9          1.278014        4           318          3       0.140267  ...
# 10         1.459029        1           413          3       0.055132  ...
# 11         1.438423        4           594          2       0.052932  ...
# 12         1.475239        1           391          2       0.050831  ...
# 13         0.821523        2           448          1       0.103629  ...
#
#     subsample  colsample_bytree  reg_alpha  reg_lambda  n           mae  \
# 0    0.940457          0.410347   0.018047   10.844207  6   6782.018602
# 1    0.703624          0.309988   0.000647    0.181209  6    648.393095
# 2    0.776860          0.354654   0.426055    1.223315  6    155.592602
# 3    0.678287          0.325641   0.011325   20.283722  6  21848.070599
# 4    0.805368          0.634436   0.218809   29.707669  6     91.668884
# 5    0.636127          0.696633   3.127948    4.019474  6   1939.975928
# 6    0.912811          0.714352   0.025224    0.972886  6    143.731049
# 7    0.667479          0.304549   0.249192    6.435538  6   7339.595864
# 8    0.626872          0.559308   0.036744    0.296260  6   6266.811551
# 9    0.960500          0.557397   0.016617    0.143196  6    218.948117
# 10   0.941320          0.811686   0.000710    0.361959  6     37.807196
# 11   0.979243          0.541799   0.001501    1.099206  6     44.065038
# 12   0.614338          0.393344   0.281116    6.778188  6   4692.029340
# 13   0.668781          0.834250   0.696717    1.399999  6    175.859240
#
#             rmse  nrmse_training_range  mean_error_bias  median_ape_pct
# 0    7060.117368              0.190002     -6782.018602       32.621125
# 1     709.670638              0.019099      -545.810676       21.012463
# 2     172.078882              0.004631       155.592602       27.616049
# 3   21989.742613              0.919165    -21848.070599       59.328379
# 4     106.100499              0.002855        91.668884       72.457937
# 5    2694.849031              0.072524      -929.094070        9.756326
# 6     144.144807              0.003879       143.731049       35.816368
# 7    8350.389027              0.224726      7339.595864       45.325014
# 8    6452.476518              0.173649     -2932.694094       33.161424
# 9     238.900364              0.006429      -218.948117       50.688473
# 10     38.988707              0.001049        37.807196      112.964103
# 11     48.477329              0.001305        44.065038       79.283034
# 12   5066.366012              0.136346      4692.029340       73.309277
# 13    185.433030              0.004990      -175.859240       44.317033
#
# [14 rows x 21 columns]
# Across-material stability:
#    folds  mean_fold_mae  sd_fold_mae  worst_fold_mae  mean_fold_rmse  \
# 0     14     3598.89765  5958.072906    21848.070599     3804.123916
#
#    sd_fold_rmse  worst_fold_rmse  mean_fold_nrmse_training_range  \
# 0   6049.471358     21989.742613                        0.125761
#
#    sd_fold_nrmse_training_range  worst_fold_nrmse_training_range
# 0                      0.242508                         0.919165
# Final recommended ESN parameters:
# res_size           26.000000
# leak_rate           0.154057
# input_magnitude     1.442532
# spectral_radius     0.355135
# washout             3.000000
# dtype: float64
# Final recommended XGBoost parameters:
# n_estimators        224.000000
# max_depth             1.000000
# learning_rate         0.109585
# min_child_weight     14.327066
# subsample             0.616775
# colsample_bytree      0.641307
# reg_alpha             0.221732
# reg_lambda           13.302078
# dtype: float64
# Saved joint fixed-parameter configuration to: /Users/markkeanujamesexconde/Library/CloudStorage/OneDrive-Personal/Documents/Academe Files/4. Doctoral/Research 1 - Warmth Sensor/Warmth-Sensor-Object-Detection/results/single_temp_esn/60C_eff_v5_final_parameters.json

# %% [markdown]
# ## Reading 3A outputs
#
# - The pooled outer OOF table is the primary unbiased performance estimate.
# - Every outer fold selects a complete ESN–XGBoost combination using training data only.
# - Outer-fold parameter selections are diagnostics and must not be averaged.
# - The JSON file contains the separate final all-material joint recommendation for 3B.
# - Rerun 3A whenever the data, feature definition, window, or joint search design changes.

# %% [markdown]
# # 9. Interpretation and handoff
#
# Notebook 3B consumes both the optimized ESN and XGBoost settings saved in the JSON
# file. Its fixed-parameter LOMO results are diagnostic; the nested outer OOF metrics
# saved here remain the primary performance claim. With 13 search dimensions, 50 trials
# are still a finite exploration—not proof of a mathematical global optimum.
